# %%
import pandas as pd
import numpy as np

r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('C:\\Users\\Onur\\Desktop\\ml-100k\\u.data', sep='\t', names=r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ['movie_id', 'title']
movies = pd.read_csv('C:\\Users\\Onur\\Desktop\\ml-100k\\u.item', sep='|', names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

ratings.head(10)
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3
# 5         1  Toy Story (1995)        5       4
# 6         1  Toy Story (1995)      109       4
# 7         1  Toy Story (1995)      181       3
# 8         1  Toy Story (1995)       95       5
# 9         1  Toy Story (1995)      268       3

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head(100)
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 96                             NaN           NaN                    NaN
# 97                             NaN           NaN                    NaN
# 98                             NaN           NaN                    NaN
# 99                             NaN           NaN                    NaN
# 100                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=200)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        NaN                  NaN
# 12 Angry Men (1957)                          NaN                  NaN
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
myRatings = userRatings.loc[32].dropna()
myRatings
# Out:
# title
# Austin Powers: International Man of Mystery (1997)    4.0
# Beavis and Butt-head Do America (1996)                2.0
# Cable Guy, The (1996)                                 2.0
# Chasing Amy (1997)                                    4.5
# Close Shave, A (1995)                                 3.0
# Con Air (1997)                                        1.0
# Dead Man Walking (1995)                               3.0
# Devil's Advocate, The (1997)                          2.0
# Devil's Own, The (1997)                               2.0
# Face/Off (1997)                                       5.0
# Fargo (1996)                                          3.0
# Fathers' Day (1997)                                   3.0
# Fierce Creatures (1997)                               3.0
# Fifth Element, The (1997)                             4.0
# George of the Jungle (1997)                           2.0
# Grosse Pointe Blank (1997)                            4.0
# ...

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print ("Adding sims for " + myRatings.index[i] + "...")
    sims = corrMatrix[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x * myRatings[i])
    simCandidates = simCandidates.append(sims)
    
print ("sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates = simCandidates.groupby(simCandidates.index).sum()
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# Adding sims for Austin Powers: International Man of Mystery (1997)...
# Adding sims for Beavis and Butt-head Do America (1996)...
# Adding sims for Cable Guy, The (1996)...
# Adding sims for Chasing Amy (1997)...
# Adding sims for Close Shave, A (1995)...
# Adding sims for Con Air (1997)...
# Adding sims for Dead Man Walking (1995)...
# Adding sims for Devil's Advocate, The (1997)...
# Adding sims for Devil's Own, The (1997)...
# Adding sims for Face/Off (1997)...
# Adding sims for Fargo (1996)...
# Adding sims for Fathers' Day (1997)...
# Adding sims for Fierce Creatures (1997)...
# Adding sims for Fifth Element, The (1997)...
# Adding sims for George of the Jungle (1997)...
# Adding sims for Grosse Pointe Blank (1997)...
# Adding sims for Jackie Chan's First Strike (1996)...
# Adding sims for Leaving Las Vegas (1995)...
# Adding sims for Liar Liar (1997)...
# Adding sims for Mars Attacks! (1996)...
# Adding sims for Men in Black (1997)...
# Adding sims for Michael (1996)...
# ...
